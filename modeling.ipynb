# %%
#bring in relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import tqdm
from sklearn.decomposition import PCA, SparsePCA
import plotly.express as px
from functions import *
from sklearn.decomposition import IncrementalPCA
from scipy import sparse
import re, seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
import xgboost
from sklearn.model_selection import RepeatedKFold

# %%
dtype_dict = {'model_name':object, 'option':object, 'piece_id':object, 'piece_description':object,
       'piece_category':object, 'type':object, 'asin':int, 'm_x': int, 'm_y': int, 'm_xy':int, 'half':int, 'dysp':int,
       'addp':int, 'storage_area':object,'Type':object,
       'Num_Notch':int, 'Area':float, 'Perimeter':float, 'Internals':int, 'Points':int, 'Num_Sizes':object,
       'Num_Breaks':int, 'Base_Size':object, 'smallest':object, 'largest':object,
       'pc_type':object, 'labels':object}

#read in datasets
df1 = pd.read_csv('program_1.csv',dtype=dtype_dict)
# df2 = pd.read_csv('program_2.csv',dtype=dtype_dict)
# df3 = pd.read_csv('program_3.csv',dtype=dtype_dict)
# df4 = pd.read_csv('program_4.csv',dtype=dtype_dict)
# df5 = pd.read_csv('program_5.csv',dtype=dtype_dict)
# df6 = pd.read_csv('program_6.csv',dtype=dtype_dict)

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)
# df2.drop('Unnamed: 0',axis=1,inplace=True)
# df3.drop('Unnamed: 0',axis=1,inplace=True)
# df4.drop('Unnamed: 0',axis=1,inplace=True)
# df5.drop('Unnamed: 0',axis=1,inplace=True)
# df6.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1.head()
# Out:
#   model_name option piece_id piece_description piece_category type  asin  m_x  \
# 0     [kinqZ  KKqN[    YFXQI         RECTANGLE          DWELT    0     4    0
# 1     [kinqZ  KKqN[    YFXQI         RECTANGLE          DWELT    0     4    0
# 2     [kinqZ  KKqN[    YFXQI         RECTANGLE          DWELT    0     4    0
# 3     [kinqZ  KVqN[    YFXQI         RECTANGLE          DWELT    0     4    0
# 4     [kinqZ  KVqN[    YFXQI         RECTANGLE          DWELT    0     4    0
#
#    m_y  m_xy  ...  Perimeter  Internals  Points Num_Sizes Num_Breaks  \
# 0    0     0  ...     112.59          3       4         1          0
# 1    0     0  ...     112.50          3       4         1          0
# 2    0     0  ...     113.00          3       4         1          0
# 3    0     0  ...     112.59          3       4         1          0
# 4    0     0  ...     112.50          3       4         1          0
#
#    Base_Size  smallest  largest  pc_type  labels
# 0          1         1        1      0.0    WELT
# 1          1         1        1      0.0    WELT
# 2          1         1        1      0.0    WELT
# 3          1         1        1      0.0    WELT
# 4          1         1        1      0.0    WELT
#
# [5 rows x 27 columns]

# %%
df1.shape
# Out:
# (496637, 27)

# %%
models = list(df1.model_name.unique())

# %%
model_dfs = []
for model in models:
    model_dfs.append(df1[df1['model_name']==model])

# %%
model_dfs[5]
# Out:
#       model_name option     piece_id piece_description piece_category type  \
# 30       [kinqLU  KKqN[        YFXQI         RECTANGLE          DWELT    0
# 31       [kinqLU  KKqN[        YFXQI         RECTANGLE          DWELT    0
# 32       [kinqLU  KKqN[        YFXQI         RECTANGLE          DWELT    0
# 33       [kinqLU  KVqN[        YFXQI         RECTANGLE          DWELT    0
# 34       [kinqLU  KVqN[        YFXQI         RECTANGLE          DWELT    0
# 35       [kinqLU  KVqN[        YFXQI         RECTANGLE          DWELT    0
# 6321     [kinqLU    0=0         FXQI   ADS DESCRIPTION           WELT    0
# 6322     [kinqLU    0=0         FXQI   ADS DESCRIPTION           WELT    0
# 6323     [kinqLU    0=0         FXQI   ADS DESCRIPTION           WELT    0
# 6324     [kinqLU    0=0         FXQI   ADS DESCRIPTION           WELT    0
# 6325     [kinqLU     KK         FXQI   ADS DESCRIPTION           WELT    0
# 6326     [kinqLU     KK         FXQI   ADS DESCRIPTION           WELT    0
# 6327     [kinqLU     KK         FXQI   ADS DESCRIPTION           WELT    0
# 6328     [kinqLU     KK         FXQI   ADS DESCRIPTION           WELT    0
# 6329     [kinqLU     KV         FXQI   ADS DESCRIPTION           WELT    0
# 6330     [kinqLU     KV         FXQI   ADS DESCRIPTION           WELT    0
# 6331     [kinqLU     KV         FXQI   ADS DESCRIPTION           WELT    0
# 6332     [kinqLU     KV         FXQI   ADS DESCRIPTION           WELT    0
# 89277    [kinqLU  KKqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89278    [kinqLU  KKqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89279    [kinqLU  KKqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89280    [kinqLU  KKqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89281    [kinqLU  KVqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89282    [kinqLU  KVqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89283    [kinqLU  KVqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 89284    [kinqLU  KVqN[  ][YFXQIgjqm         RECTANGLE    ABDWELT74-1    0
# 90734    [kinqLU    0=0    [FXQIgjqm                 A      BWELT74-1    0
# 90735    [kinqLU    0=0    [FXQIgjqm                 A      BWELT74-1    0
# 90736    [kinqLU     KK    [FXQIgjqm                 A      BWELT74-1    0
# 90737    [kinqLU     KK    [FXQIgjqm                 A      BWELT74-1    0
# 90738    [kinqLU     KV    [FXQIgjqm                 A      BWELT74-1    0
# 90739    [kinqLU     KV    [FXQIgjqm                 A      BWELT74-1    0
# 91147    [kinqLU    0=0  [kinqLqN[qZ         RECTANGLE           OB-C    0
# 91148    [kinqLU  KKqN[  [kinqLqN[qZ         RECTANGLE           OB-C    0
# 91149    [kinqLU  KVqN[  [kinqLqN[qZ         RECTANGLE           OB-C    0
# 91153    [kinqLU    0=0  [kinqLqN[qJ         RECTANGLE           OB-S    0
# 91154    [kinqLU  KKqN[  [kinqLqN[qJ         RECTANGLE           OB-S    0
# 91155    [kinqLU  KVqN[  [kinqLqN[qJ         RECTANGLE           OB-S    0
# 91159    [kinqLU    0=0  [kinqLqN[qm         RECTANGLE           OB-1    0
# 91160    [kinqLU  KKqN[  [kinqLqN[qm         RECTANGLE           OB-1    0
# 91161    [kinqLU  KVqN[  [kinqLqN[qm         RECTANGLE           OB-1    0
# 91165    [kinqLU    0=0  [kinqLqU[qZ         RECTANGLE           HB-C    0
# 91166    [kinqLU     KK  [kinqLqU[qZ         RECTANGLE           HB-C    0
# 91167    [kinqLU     KV  [kinqLqU[qZ         RECTANGLE           HB-C    0
# 91171    [kinqLU    0=0  [kinqLqU[qJ         RECTANGLE           HB-S    0
# 91172    [kinqLU     KK  [kinqLqU[qJ         RECTANGLE           HB-S    0
# 91173    [kinqLU     KV  [kinqLqU[qJ         RECTANGLE           HB-S    0
#
#        asin  m_x  m_y  m_xy  ...  Perimeter  Internals  Points Num_Sizes  \
# 30        4    0    0     0  ...     112.59          3       4         1
# 31        4    0    0     0  ...     112.50          3       4         1
# 32        4    0    0     0  ...     113.00          3       4         1
# 33        4    0    0     0  ...     112.59          3       4         1
# 34        4    0    0     0  ...     112.50          3       4         1
# 35        4    0    0     0  ...     113.00          3       4         1
# 6321      7    0    0     0  ...     110.58          1       4         1
# 6322      7    0    0     0  ...     111.00          1       4         1
# 6323      7    0    0     0  ...     280.88          1       4         1
# 6324      7    0    0     0  ...     110.58          1       4         5
# 6325      7    0    0     0  ...     110.58          1       4         1
# 6326      7    0    0     0  ...     111.00          1       4         1
# 6327      7    0    0     0  ...     280.88          1       4         1
# 6328      7    0    0     0  ...     110.58          1       4         5
# 6329      7    0    0     0  ...     110.58          1       4         1
# 6330      7    0    0     0  ...     111.00          1       4         1
# 6331      7    0    0     0  ...     280.88          1       4         1
# 6332      7    0    0     0  ...     110.58          1       4         5
# 89277     4    0    0     0  ...     152.30          1       4         1
# 89278     4    0    0     0  ...     152.50          1       4         1
# 89279     4    0    0     0  ...     152.75          1       4         1
# 89280     4    0    0     0  ...     153.00          1       4         1
# 89281     4    0    0     0  ...     152.30          1       4         1
# 89282     4    0    0     0  ...     152.50          1       4         1
# 89283     4    0    0     0  ...     152.75          1       4         1
# 89284     4    0    0     0  ...     153.00          1       4         1
# 90734     7    0    0     0  ...     150.93          1       4         1
# 90735     7    0    0     0  ...     151.50          1       4         1
# 90736     7    0    0     0  ...     150.93          1       4         1
# 90737     7    0    0     0  ...     151.50          1       4         1
# 90738     7    0    0     0  ...     150.93          1       4         1
# 90739     7    0    0     0  ...     151.50          1       4         1
# 91147     1    0    0     0  ...     191.41          3       7         1
# 91148     0    0    0     0  ...     191.41          3       7         1
# 91149     1    0    0     0  ...     191.41          3       7         1
# 91153     1    0    1     0  ...      97.71          3       5         1
# 91154     0    0    0     0  ...      97.71          3       5         1
# 91155     1    0    1     0  ...      97.71          3       5         1
# 91159     1    0    0     0  ...     215.41          3       7         1
# 91160     1    0    0     0  ...     215.41          3       7         1
# 91161     0    0    0     0  ...     215.41          3       7         1
# 91165     1    0    0     0  ...     166.41          3       7         1
# 91166     1    0    0     0  ...     166.41          3       7         1
# 91167     1    0    0     0  ...     166.41          3       7         1
# 91171     1    0    1     0  ...     122.71          3       5         1
# 91172     1    0    1     0  ...     122.71          3       5         1
# 91173     1    0    1     0  ...     122.71          3       5         1
#
#       Num_Breaks  Base_Size  smallest  largest  pc_type  labels
# 30             0          1         1        1      0.0    WELT
# 31             0          1         1        1      0.0    WELT
# 32             0          1         1        1      0.0    WELT
# 33             0          1         1        1      0.0    WELT
# 34             0          1         1        1      0.0    WELT
# 35             0          1         1        1      0.0    WELT
# 6321           0          1         1        1      0.0    WELT
# 6322           0          1         1        1      0.0    WELT
# 6323           0          1         1        1      0.0    WELT
# 6324           3          1         1        4      0.0    WELT
# 6325           0          1         1        1      0.0    WELT
# 6326           0          1         1        1      0.0    WELT
# 6327           0          1         1        1      0.0    WELT
# 6328           3          1         1        4      0.0    WELT
# 6329           0          1         1        1      0.0    WELT
# 6330           0          1         1        1      0.0    WELT
# 6331           0          1         1        1      0.0    WELT
# 6332           3          1         1        4      0.0    WELT
# 89277          0          1         1        1      0.0    WELT
# 89278          0          1         1        1      0.0    WELT
# 89279          0          1         1        1      0.0    WELT
# 89280          0          1         1        1      0.0    WELT
# 89281          0          1         1        1      0.0    WELT
# 89282          0          1         1        1      0.0    WELT
# 89283          0          1         1        1      0.0    WELT
# 89284          0          1         1        1      0.0    WELT
# 90734          0          1         1        1      0.0    WELT
# 90735          0          1         1        1      0.0    WELT
# 90736          0          1         1        1      0.0    WELT
# 90737          0          1         1        1      0.0    WELT
# 90738          0          1         1        1      0.0    WELT
# 90739          0          1         1        1      0.0    WELT
# 91147          0          1         1        1      0.0      OB
# 91148          0          1         1        1      0.0      OB
# 91149          0          1         1        1      0.0      OB
# 91153          0          1         1        1      0.0      OB
# 91154          0          1         1        1      0.0      OB
# 91155          0          1         1        1      0.0      OB
# 91159          0          1         1        1      0.0      OB
# 91160          0          1         1        1      0.0      OB
# 91161          0          1         1        1      0.0      OB
# 91165          0          1         1        1      0.0      HB
# 91166          0          1         1        1      0.0      HB
# 91167          0          1         1        1      0.0      HB
# 91171          0          1         1        1      0.0      HB
# 91172          0          1         1        1      0.0      HB
# 91173          0          1         1        1      0.0      HB
#
# [47 rows x 27 columns]
